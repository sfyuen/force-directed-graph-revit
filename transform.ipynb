# %%
# !pip install "pandas>=1.5.3"
# !pip install "numpy>=1.25.2"
# Out:
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.3) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.3) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.5.3) (1.16.0)
# Requirement already satisfied: numpy>=1.25.2 in /usr/local/lib/python3.10/dist-packages (1.25.2)

# %%
import json
import pandas as pd
import operator
import numpy as np
from collections import Counter
f = open(f'sample/raw.json',"r",encoding="utf-8")
data = json.load(f)

# %% [markdown]
# Number of records:

# %%
print(len(data))
# Out:
# 47

# %% [markdown]
# Filtering properties with empty values

# %%
for x in data:
  cleaned_empty_value=[]
  for y in x['properties']:
    if y['displayValue']!='':
      cleaned_empty_value.append(y)
  x['properties']=cleaned_empty_value

# %% [markdown]
# Load all properties to Pandas Dataframe

# %%
attrs=[]
vals=[]
for x in data:
  for y in x['properties']:
    attrs.append(y['displayName'])
    vals.append(y['displayValue'])


df_attr = pd.DataFrame({"attribute":attrs,"value":vals})
df_attr.groupby(['attribute',"value"]).size()
# Out:
# attribute          value
# 12 Circuit Height  1.9166666666666665                               26
#                    3.6666666666666665                               11
# 24 Circuit Height  2.1666666666666665                               26
#                    3.6666666666666665                               11
# 30 Circuit Height  2.4166666666666665                               26
#                                                                     ..
# viewable_in        edb989ed-57fa-4318-88c9-6ba95b7b945f-000276db     2
#                    edb989ed-57fa-4318-88c9-6ba95b7b945f-000276e2     5
#                    f16d99ba-9667-4ad2-bb20-70f866953194-00167ffc     1
#                    f16d99ba-9667-4ad2-bb20-70f866953194-0016802c     1
#                    f16d99ba-9667-4ad2-bb20-70f866953194-00168035     4
# Length: 1266, dtype: int64

# %% [markdown]
# Unique property keys

# %%
pd.DataFrame(df_attr['attribute'].unique())
# Out:
#                         0
# 0                  parent
# 1             viewable_in
# 2                Category
# 3              CategoryId
# 4                   Level
# ..                    ...
# 93      12 Circuit Height
# 94    Load Classification
# 95       OmniClass Number
# 96       ADSK MS Comments
# 97  Schedule Header Notes
#
# [98 rows x 1 columns]

# %% [markdown]
# Number of unique values under each keys

# %%
df_attr.groupby('attribute')["value"].nunique().sort_values()
# Out:
# attribute
# Lighting - Exterior Connected Current     1
# Neutral Rating                            1
# Neutral Bus                               1
# Max Number of Circuits                    1
# Distribution System                       1
#                                          ..
# Mark                                     47
# ElementId                                47
# Current Phase A                          47
# IfcGUID                                  47
# Panel Name                               47
# Name: value, Length: 98, dtype: int64

# %% [markdown]
# Finding some attribute keys with medium distinct key size (manually select as >5 and <15)

# %%
df_fil = df_attr.groupby('attribute')["value"].nunique()

# %%
with pd.option_context('display.max_colwidth', None,
                       'display.max_columns', None,
                       'display.max_rows', None):
  display(df_attr[df_attr['attribute'].isin(df_fil[operator.and_(df_fil>5, df_fil <15)].index)].groupby('attribute')["value"].value_counts().to_frame())
# Out:
#                                                                value
# attribute                              value
# Circuit Number                         2                          10
#                                        1                           9
#                                        3                           9
#                                        4                           7
#                                        5                           3
#                                        1,3,5                       1
#                                        13,15,17                    1
#                                        14,16,18                    1
#                                        19,21,23                    1
#                                        2,4,6                       1
#                                        20,22,24                    1
#                                        7,9,11                      1
#                                        8,10,12                     1
# Depth                                  0.4791666666666667         37
#                                        0.5908203125                5
#                                        0.6741536458333333          2
#                                        0.9267578125                1
#                                        1.0784505208333333          1
#                                        3                           1
# Elevation from Level                   4                          36
#                                        4.739908854166716           3
#                                        3.9065755208333837          2
#                                        0.5416666666666679          1
#                                        1.4999999999999982          1
#                                        4.489908854166716           1
#                                        4.75000000000005            1
#                                        5.35742187500005            1
#                                        5.46582031250005            1
# HVAC Connected                         9999.990000000002          20
#                                        19999.980000000003          8
#                                        39999.96000000001           3
#                                        49999.95000000001           2
#                                        29999.97                    1
#                                        59999.94000000002           1
#                                        89999.91000000003           1
#                                        129999.87000000005          1
#                                        239999.7600000001           1
#                                        369999.6300000002           1
# HVAC Connected Current                 27.757196723045997         20
#                                        55.514393446091994          8
#                                        111.02878689218399          3
#                                        138.78598361523             2
#                                        83.271590169138             1
#                                        166.54318033827602          1
#                                        249.81477050741404          1
#                                        360.84355739959807          1
#                                        666.1727213531042           1
#                                        1027.0162787527024          1
# HVAC Estimated Demand                  9999.990000000002          20
#                                        19999.980000000003          8
#                                        39999.96000000001           3
#                                        49999.95000000001           2
#                                        29999.97                    1
#                                        59999.94000000002           1
#                                        89999.91000000003           1
#                                        129999.87000000005          1
#                                        239999.7600000001           1
#                                        369999.6300000002           1
# HVAC Estimated Demand Current          27.757196723045997         20
#                                        55.514393446091994          8
#                                        111.02878689218399          3
#                                        138.78598361523             2
#                                        83.271590169138             1
#                                        166.54318033827602          1
#                                        249.81477050741404          1
#                                        360.84355739959807          1
#                                        666.1727213531042           1
#                                        1027.0162787527024          1
# Height                                 2.1666666666666665         22
#                                        3.6666666666666665         10
#                                        2.4166666666666665          4
#                                        4.343424479166666           3
#                                        5.1767578125                2
#                                        3.6175130208333335          1
#                                        3.725911458333333           1
#                                        4.333333333333333           1
#                                        4.593424479166666           1
#                                        4.666666666666667           1
#                                        7.625                       1
# Lighting - Dwelling Unit Demand Factor 100                        36
#                                        49.13658112222704           1
#                                        50.973132372214934          1
#                                        52.18061674008809           1
#                                        52.302573203194314          1
#                                        75.12345679012346           1
# MCB Rating                             100                        26
#                                        0                           9
#                                        225                         9
#                                        200                         1
#                                        800                         1
#                                        3000                        1
# Mains                                  100                        31
#                                        0                           7
#                                        200                         5
#                                        800                         1
#                                        1200                        1
#                                        1600                        1
#                                        3000                        1
# Power Connected                        360                        18
#                                        180                        11
#                                        540                         2
#                                        1620                        2
#                                        0                           1
#                                        900                         1
#                                        1080                        1
#                                        1259.9999999999998          1
#                                        1439.9999999999998          1
#                                        1980                        1
#                                        4500.000000000001           1
#                                        5040.000000000002           1
#                                        9540.000000000004           1
# Power Connected Current                0.9992600812897371         18
#                                        0.49963004064486854        11
#                                        1.4988901219346056          2
#                                        4.4966703658038165          2
#                                        0                           1
#                                        2.4981502032243426          1
#                                        2.997780243869211           1
#                                        3.4974102845140793          1
#                                        3.997040325158948           1
#                                        5.495930447093555           1
#                                        12.490751016121717          1
#                                        13.989641138056323          1
#                                        26.480392154178045          1
# Power Estimated Demand                 360                        18
#                                        180                        11
#                                        540                         2
#                                        1620                        2
#                                        0                           1
#                                        900                         1
#                                        1080                        1
#                                        1259.9999999999998          1
#                                        1439.9999999999998          1
#                                        1980                        1
#                                        4500.000000000001           1
#                                        5040.000000000002           1
#                                        9540.000000000004           1
# Power Estimated Demand Current         0.9992600812897371         18
#                                        0.49963004064486854        11
#                                        1.4988901219346056          2
#                                        4.4966703658038165          2
#                                        0                           1
#                                        2.4981502032243426          1
#                                        2.997780243869211           1
#                                        3.4974102845140793          1
#                                        3.997040325158948           1
#                                        5.495930447093555           1
#                                        12.490751016121717          1
#                                        13.989641138056323          1
#                                        26.480392154178045          1
# Receptacle Demand Factor               100                        40
#                                        55.97371565113504           1
#                                        60.10101010101014           1
#                                        64.61988304093573           1
#                                        72.58355916892506           1
#                                        86.5497076023392            1
#                                        94.80286738351253           1
# Schedule Level                         L4                         10
#                                        L3                          8
#                                        L2                          5
#                                        L5                          5
#                                        L1 - Block 37               3
#                                        L1 - Block 43               2
#                                        Parking                     2
#                                        L1 - Block 35               1
#                                        R2                          1
# Supply From                            HDP                         8
#                                        MB22                        5
#                                        MB23                        5
#                                        MAIN1                       4
#                                        MB11                        4
#                                        MB12                        4
#                                        MB13                        4
#                                        MB21                        4
#                                        MAIN2                       3
#                                        MB14                        3
#                                        SWITCHBOARD                 2
# Total Demand Factor                    100                        38
#                                        89.51498543897499           1
#                                        90.50890295183272           1
#                                        91.55000989815807           1
#                                        92.1731300073756            1
#                                        92.31643405747973           1
#                                        93.43276267714857           1
#                                        97.41586969655626           1
#                                        98.9920586354226            1
#                                        106.4162759057686           1
# Type IfcGUID                           3M$Qtr4nbCV99j7973jyiS     26
#                                        01rOGBYFL9IBD8p4B5gSFL      7
#                                        3M$Qtr4nbCV99j7973jyiU      4
#                                        26ZxIv1I98_g3agdzkxkPF      3
#                                        26ZxIv1I98_g3agdzkxkPD      2
#                                        26ZxIv1I98_g3agdzkxkP9      1
#                                        26ZxIv1I98_g3agdzkxkPB      1
#                                        26ZxIv1I98_g3agdzkxkeB      1
#                                        26ZxIv1I98_g3agdzkxkeD      1
#                                        2JDXA9$nn0Rhl8JXvx5GUT      1
# Type Name                              100 A                      26
#                                        225 A                      11
#                                        125A - 4 Socket             3
#                                        125A - 5 Socket             2
#                                        1200A                       1
#                                        1600A                       1
#                                        225A - 3 Socket             1
#                                        225A - 4 Socket             1
#                                        Two Section                 1
# Width                                  1.25                       26
#                                        1.6666666666666665         11
#                                        1.0208333333333333          5
#                                        1.4482421875                2
#                                        1.8665364583333335          1
#                                        2.7633463541666665          1
#                                        6                           1
# parent                                 8555                       26
#                                        12267                       7
#                                        8556                        4
#                                        13000                       3
#                                        13001                       2
#                                        12996                       1
#                                        12997                       1
#                                        13002                       1
#                                        13003                       1
#                                        13010                       1

# %% [markdown]
# Finding attributes with all distinct values

# %%
df_attr.groupby('attribute')["value"].nunique().sort_values()[df_attr.groupby('attribute')["value"].nunique().sort_values()==len(data)]
# Out:
# attribute
# Mark               47
# ElementId          47
# Current Phase A    47
# IfcGUID            47
# Panel Name         47
# Name: value, dtype: int64

# %% [markdown]
# The "name" attribute from raw data can be considered as the category of objects

# %%
all_names=Counter()
for x in data:
  all_names[x['name']]+=1

for k,v in all_names.items():
  print(k,v)
# Out:
# Meter Main 2
# Meter Bank 7
# Switchboard 1
# Lighting and Appliance Panelboard - 208V MCB 30
# Lighting and Appliance Panelboard - 208V MCB - Surface 7

# %% [markdown]
# Finally the following attributes were selected for output
# 1. Mains
# 2. MCB Rating
# 3. Supply From: The upstream equipment (in Panel Name)
# 4. Panel Name: The name of equipment
# 5. Scedule Level/Level: physical location of the equipment

# %%
target_attr=("Mains","MCB Rating","Supply From","Panel Name","Schedule Level", "Level")
attr_with_unit=("Mains","MCB Rating")
to_df = []
for x in data:
  row = {}
  row['name']=x['name']
  for y in x['properties']:
    if y['displayName'] in target_attr:
      row[y['displayName']] = y['displayValue']
    if y['displayName'] in attr_with_unit:
      row[y['displayName']+"_unit"] = y['units']
  to_df.append(row)

# %%
df = pd.DataFrame.from_records(to_df)
df.head()
# Out:
#          name    Level  Mains                        Mains_unit  MCB Rating  \
# 0  Meter Main  Parking   1600  autodesk.unit.unit:amperes-1.0.0           0
# 1  Meter Main  Parking   1200  autodesk.unit.unit:amperes-1.0.0           0
# 2  Meter Bank  Parking      0  autodesk.unit.unit:amperes-1.0.0           0
# 3  Meter Bank  Parking      0  autodesk.unit.unit:amperes-1.0.0           0
# 4  Meter Bank  Parking      0  autodesk.unit.unit:amperes-1.0.0           0
#
#                     MCB Rating_unit  Supply From Panel Name Schedule Level
# 0  autodesk.unit.unit:amperes-1.0.0  SWITCHBOARD      MAIN1            NaN
# 1  autodesk.unit.unit:amperes-1.0.0  SWITCHBOARD      MAIN2            NaN
# 2  autodesk.unit.unit:amperes-1.0.0        MAIN1       MB11            NaN
# 3  autodesk.unit.unit:amperes-1.0.0        MAIN1       MB12            NaN
# 4  autodesk.unit.unit:amperes-1.0.0        MAIN2       MB21            NaN

# %% [markdown]
# Checking all records of Mains/MCB Rating have the same unit

# %%
print("Mains_unit: ",df['Mains_unit'].unique())
print("MCB Rating unit: ",df['MCB Rating_unit'].unique())
# Out:
# Mains_unit:  ['autodesk.unit.unit:amperes-1.0.0']
# MCB Rating unit:  ['autodesk.unit.unit:amperes-1.0.0']

# %% [markdown]
# Adding unit (A) for Mains/MCB Rating

# %%
df = df.drop(columns=['Mains_unit',"MCB Rating_unit"])
df['Mains']=df['Mains'].apply(lambda x:str(x)+" A" if x!=0 else np.nan)
df['MCB Rating']=df['MCB Rating'].apply(lambda x:str(x)+" A" if x!=0 else np.nan)

# %%
df[['Panel Name','Mains','MCB Rating']].head(10)
# Out:
#     Panel Name   Mains MCB Rating
# 0        MAIN1  1600 A        NaN
# 1        MAIN2  1200 A        NaN
# 2         MB11     NaN        NaN
# 3         MB12     NaN        NaN
# 4         MB21     NaN        NaN
# 5         MB22     NaN        NaN
# 6         MB23     NaN        NaN
# 7         MB14     NaN        NaN
# 8         MB13     NaN        NaN
# 9  SWITCHBOARD  3000 A     3000 A

# %% [markdown]
# The level of equipment were recorded in two different attributes (Level & Schedule Level)

# %%
df[['Level','Schedule Level']]
# Out:
#       Level Schedule Level
# 0   Parking            NaN
# 1   Parking            NaN
# 2   Parking            NaN
# 3   Parking            NaN
# 4   Parking            NaN
# 5   Parking            NaN
# 6   Parking            NaN
# 7   Parking            NaN
# 8   Parking            NaN
# 9   Parking            NaN
# 10      NaN             L5
# 11      NaN             L4
# 12      NaN             L3
# 13      NaN             L2
# 14      NaN             L5
# 15      NaN             L5
# 16      NaN             L4
# 17      NaN             L4
# 18      NaN             L3
# 19      NaN             L3
# 20      NaN             L2
# 21      NaN             L2
# 22      NaN             L2
# 23      NaN             L2
# 24      NaN             L4
# 25      NaN             L4
# 26      NaN             L4
# 27      NaN             L4
# 28      NaN             L3
# 29      NaN             L3
# 30      NaN             L3
# 31      NaN             L3
# 32      NaN             L4
# 33      NaN             L3
# 34      NaN             L5
# 35      NaN             L5
# 36      NaN             L4
# 37      NaN  L1 - Block 43
# 38      NaN  L1 - Block 43
# 39      NaN             L4
# 40      NaN  L1 - Block 37
# 41      NaN  L1 - Block 37
# 42      NaN  L1 - Block 37
# 43      NaN  L1 - Block 35
# 44      NaN             R2
# 45      NaN        Parking
# 46      NaN        Parking

# %% [markdown]
# No records have both "Level" and "Schedule Level" values

# %%
operator.and_((~df['Level'].isna()), (~df['Schedule Level'].isna())).all()
# Out:
# False

# %% [markdown]
# Merge the record from "Schedule Level" to "Level"

# %%
df["Level"] = df.apply(lambda x: (x["Schedule Level"] if pd.isnull(x["Level"]) else x["Level"]), axis=1)
df = df.drop(columns=['Schedule Level'])
df["Level"]
# Out:
# 0           Parking
# 1           Parking
# 2           Parking
# 3           Parking
# 4           Parking
# 5           Parking
# 6           Parking
# 7           Parking
# 8           Parking
# 9           Parking
# 10               L5
# 11               L4
# 12               L3
# 13               L2
# 14               L5
# 15               L5
# 16               L4
# 17               L4
# 18               L3
# 19               L3
# 20               L2
# 21               L2
# 22               L2
# 23               L2
# 24               L4
# 25               L4
# 26               L4
# 27               L4
# 28               L3
# 29               L3
# 30               L3
# 31               L3
# 32               L4
# 33               L3
# 34               L5
# 35               L5
# 36               L4
# 37    L1 - Block 43
# 38    L1 - Block 43
# 39               L4
# 40    L1 - Block 37
# 41    L1 - Block 37
# 42    L1 - Block 37
# 43    L1 - Block 35
# 44               R2
# 45          Parking
# 46          Parking
# Name: Level, dtype: object

# %%
df
# Out:
#                                                  name          Level   Mains  \
# 0                                          Meter Main        Parking  1600 A
# 1                                          Meter Main        Parking  1200 A
# 2                                          Meter Bank        Parking     NaN
# 3                                          Meter Bank        Parking     NaN
# 4                                          Meter Bank        Parking     NaN
# 5                                          Meter Bank        Parking     NaN
# 6                                          Meter Bank        Parking     NaN
# 7                                          Meter Bank        Parking     NaN
# 8                                          Meter Bank        Parking     NaN
# 9                                         Switchboard        Parking  3000 A
# 10       Lighting and Appliance Panelboard - 208V MCB             L5   100 A
# 11       Lighting and Appliance Panelboard - 208V MCB             L4   100 A
# 12       Lighting and Appliance Panelboard - 208V MCB             L3   100 A
# 13       Lighting and Appliance Panelboard - 208V MCB             L2   100 A
# 14       Lighting and Appliance Panelboard - 208V MCB             L5   100 A
# 15       Lighting and Appliance Panelboard - 208V MCB             L5   100 A
# 16       Lighting and Appliance Panelboard - 208V MCB             L4   100 A
# 17       Lighting and Appliance Panelboard - 208V MCB             L4   100 A
# 18       Lighting and Appliance Panelboard - 208V MCB             L3   100 A
# 19       Lighting and Appliance Panelboard - 208V MCB             L3   100 A
# 20       Lighting and Appliance Panelboard - 208V MCB             L2   100 A
# 21       Lighting and Appliance Panelboard - 208V MCB             L2   100 A
# 22       Lighting and Appliance Panelboard - 208V MCB             L2   100 A
# 23       Lighting and Appliance Panelboard - 208V MCB             L2   100 A
# 24       Lighting and Appliance Panelboard - 208V MCB             L4   100 A
# 25       Lighting and Appliance Panelboard - 208V MCB             L4   100 A
# 26       Lighting and Appliance Panelboard - 208V MCB             L4   100 A
# 27       Lighting and Appliance Panelboard - 208V MCB             L4   100 A
# 28       Lighting and Appliance Panelboard - 208V MCB             L3   100 A
# 29       Lighting and Appliance Panelboard - 208V MCB             L3   100 A
# 30       Lighting and Appliance Panelboard - 208V MCB             L3   100 A
# 31       Lighting and Appliance Panelboard - 208V MCB             L3   200 A
# 32       Lighting and Appliance Panelboard - 208V MCB             L4   100 A
# 33       Lighting and Appliance Panelboard - 208V MCB             L3   200 A
# 34       Lighting and Appliance Panelboard - 208V MCB             L5   100 A
# 35       Lighting and Appliance Panelboard - 208V MCB             L5   100 A
# 36       Lighting and Appliance Panelboard - 208V MCB             L4   100 A
# 37       Lighting and Appliance Panelboard - 208V MCB  L1 - Block 43   200 A
# 38       Lighting and Appliance Panelboard - 208V MCB  L1 - Block 43   200 A
# 39       Lighting and Appliance Panelboard - 208V MCB             L4   100 A
# 40  Lighting and Appliance Panelboard - 208V MCB -...  L1 - Block 37   100 A
# 41  Lighting and Appliance Panelboard - 208V MCB -...  L1 - Block 37   200 A
# 42  Lighting and Appliance Panelboard - 208V MCB -...  L1 - Block 37   100 A
# 43  Lighting and Appliance Panelboard - 208V MCB -...  L1 - Block 35   100 A
# 44  Lighting and Appliance Panelboard - 208V MCB -...             R2   100 A
# 45  Lighting and Appliance Panelboard - 208V MCB -...        Parking   100 A
# 46  Lighting and Appliance Panelboard - 208V MCB -...        Parking   800 A
#
#    MCB Rating  Supply From   Panel Name
# 0         NaN  SWITCHBOARD        MAIN1
# 1         NaN  SWITCHBOARD        MAIN2
# 2         NaN        MAIN1         MB11
# 3         NaN        MAIN1         MB12
# 4         NaN        MAIN2         MB21
# 5         NaN        MAIN2         MB22
# 6         NaN        MAIN2         MB23
# 7         NaN        MAIN1         MB14
# 8         NaN        MAIN1         MB13
# 9      3000 A          NaN  SWITCHBOARD
# 10      100 A         MB21         P506
# 11      100 A         MB23         P408
# 12      100 A         MB12         P307
# 13      100 A         MB21         P205
# 14      100 A         MB21         P507
# 15      100 A         MB11         P504
# 16      100 A         MB23         P410
# 17      100 A         MB22         P404
# 18      100 A         MB22         P309
# 19      100 A         MB12         P304
# 20      100 A         MB11         P203
# 21      100 A         MB11         P202
# 22      100 A         MB21         P204
# 23      100 A          HDP         P200
# 24      100 A         MB22         P403
# 25      100 A         MB22         P405
# 26      100 A         MB23         P407
# 27      100 A         MB23         P409
# 28      100 A         MB12         P306
# 29      100 A         MB22         P308
# 30      100 A         MB12         P303
# 31      100 A         MB14         P301
# 32      100 A         MB23         P406
# 33      100 A          HDP         P300
# 34      100 A          HDP         P500
# 35      100 A         MB14         P501
# 36      225 A         MB14         P401
# 37      225 A         MB13         P109
# 38      225 A         MB13         P108
# 39      225 A          HDP         P400
# 40      225 A          HDP       P106/7
# 41      225 A          HDP          EL1
# 42      225 A         MB11         P105
# 43      225 A         MB13         P102
# 44      200 A          HDP       P-Roof
# 45      225 A          HDP        LP000
# 46      800 A         MB13          HDP

# %% [markdown]
# Transform the dataframe into nodes/edges information

# %%
df_res=df.reset_index()
df_res=df_res.rename({'index': 'id', 'name': 'group', 'Panel Name':'name','MCB Rating':"MCB_Rating"}, axis=1)

# %%
df_nodes=df_res.drop('Supply From', axis=1)

# %% [markdown]
# Final result of nodes dataframe

# %%
df_nodes.head()
# Out:
#    id       group    Level   Mains MCB_Rating   name
# 0   0  Meter Main  Parking  1600 A        NaN  MAIN1
# 1   1  Meter Main  Parking  1200 A        NaN  MAIN2
# 2   2  Meter Bank  Parking     NaN        NaN   MB11
# 3   3  Meter Bank  Parking     NaN        NaN   MB12
# 4   4  Meter Bank  Parking     NaN        NaN   MB21

# %% [markdown]
# self-join the record based on the "Supply From" attribute

# %%
df_links=df_res.merge(df_res,left_on="Supply From",right_on="name")

# %%
df_links.head()
# Out:
#    id_x     group_x  Level_x Mains_x MCB_Rating_x Supply From_x name_x  id_y  \
# 0     0  Meter Main  Parking  1600 A          NaN   SWITCHBOARD  MAIN1     9
# 1     1  Meter Main  Parking  1200 A          NaN   SWITCHBOARD  MAIN2     9
# 2     2  Meter Bank  Parking     NaN          NaN         MAIN1   MB11     0
# 3     3  Meter Bank  Parking     NaN          NaN         MAIN1   MB12     0
# 4     7  Meter Bank  Parking     NaN          NaN         MAIN1   MB14     0
#
#        group_y  Level_y Mains_y MCB_Rating_y Supply From_y       name_y
# 0  Switchboard  Parking  3000 A       3000 A           NaN  SWITCHBOARD
# 1  Switchboard  Parking  3000 A       3000 A           NaN  SWITCHBOARD
# 2   Meter Main  Parking  1600 A          NaN   SWITCHBOARD        MAIN1
# 3   Meter Main  Parking  1600 A          NaN   SWITCHBOARD        MAIN1
# 4   Meter Main  Parking  1600 A          NaN   SWITCHBOARD        MAIN1

# %% [markdown]
# Output the results of link in terms of id

# %%
df_links=df_links.rename({"id_x":"target","id_y":"source"}, axis=1)[["source","target"]]

# %% [markdown]
# Final result of links dataframe

# %%
df_links.head()
# Out:
#    source  target
# 0       9       0
# 1       9       1
# 2       0       2
# 3       0       3
# 4       0       7

# %% [markdown]
# Export the result to JSON file

# %%
df_nodes.fillna("N/A").to_json(r'df_nodes.json',orient='records')

# %%
df_links.to_json(r'df_links.json',orient='records')
